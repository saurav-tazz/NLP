# %%
import nltk
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
import nltk
nltk.download(['punkt', 'punkt_tab', 'stopwords', 'wordnet'])
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [raw]
# pip install nltk

# %%
text = "Natural Language Processing (NLP) is transforming how computer understands human language "

# %%
text = text.lower()
print("lowercased: ", text)
# Out:
# lowercased:  natural language processing (nlp) is transforming how computer understands human language

# %%
tokens = word_tokenize(text)
print("Tokens: ", tokens)
# Out:
# Tokens:  ['natural', 'language', 'processing', '(', 'nlp', ')', 'is', 'transforming', 'how', 'computer', 'understands', 'human', 'language']

# %%
stemmer = PorterStemmer()
stemmed = [stemmer.stem(t) for t in tokens]
print("Stemmed: ", stemmed)
# Out:
# Stemmed:  ['natur', 'languag', 'process', '(', 'nlp', ')', 'is', 'transform', 'how', 'comput', 'understand', 'human', 'languag']

# %%
lemmatizer = WordNetLemmatizer()
lemmatized = [lemmatizer.lemmatize(t) for t in tokens]
print("Lemmatized: ", lemmatized)
# Out:
# Lemmatized:  ['natural', 'language', 'processing', '(', 'nlp', ')', 'is', 'transforming', 'how', 'computer', 'understands', 'human', 'language']

# %%
tokens = [t for t in tokens if t not in string.punctuation]
print("no punctuation:",tokens)
# Out:
# no punctuation: ['natural', 'language', 'processing', 'nlp', 'is', 'transforming', 'how', 'computer', 'understands', 'human', 'language']
